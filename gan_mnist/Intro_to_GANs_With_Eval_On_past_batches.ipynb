# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN](https://github.com/junyanz/CycleGAN)
# * [A whole list](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes fake data to pass to the discriminator. The discriminator also sees real data and predicts if the data it's received is real or fake. The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real data. And the discriminator is trained to figure out which data is real and which is fake. What ends up happening is that the generator learns to make data that is indistiguishable from real data to the discriminator.
#
# ![GAN diagram](assets/gan_diagram.png)
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector the generator uses to contruct it's fake images. As the generator learns through training, it figures out how to map these random vectors to recognizable images that can fool the discriminator.
#
# The output of the discriminator is a sigmoid function, where 0 indicates a fake image and 1 indicates an real image. If you're interested only in generating new images, you can throw out the discriminator after training. Now, let's see how we build this thing in TensorFlow.

# %%
# %matplotlib inline

import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model Inputs
#
# First we need to create the inputs for our graph. We need two inputs, one for the discriminator and one for the generator. Here we'll call the discriminator input `inputs_real` and the generator input `inputs_z`. We'll assign them the appropriate sizes for each of the networks.
#
# >**Exercise:** Finish the `model_inputs` function below. Create the placeholders for `inputs_real` and `inputs_z` using the input sizes `real_dim` and `z_dim` respectively.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, real_dim, name = 'inputs_real')
    inputs_z =  tf.placeholder(tf.float32, z_dim, name = 'inputs_z')
    inputs_past =  tf.placeholder(tf.float32, real_dim, name = 'inputs_past')
    
    return inputs_real, inputs_z, inputs_past

# %% [markdown]
# ## Generator network
#
# ![GAN Network](assets/gan_network.png)
#
# Here we'll build the generator network. To make this network a universal function approximator, we'll need at least one hidden layer. We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# #### Variable Scope
# Here we need to use `tf.variable_scope` for two reasons. Firstly, we're going to make sure all the variable names start with `generator`. Similarly, we'll prepend `discriminator` to the discriminator variables. This will help out later when we're training the separate networks.
#
# We could just use `tf.name_scope` to set the names, but we also want to reuse these networks with different inputs. For the generator, we're going to train it, but also _sample from it_ as we're training and after training. The discriminator will need to share variables between the fake and real input images. So, we can use the `reuse` keyword for `tf.variable_scope` to tell TensorFlow to reuse the variables instead of creating new ones if we build the graph again.
#
# To use `tf.variable_scope`, you use a `with` statement:
# ```python
# with tf.variable_scope('scope_name', reuse=False):
#     # code here
# ```
#
# Here's more from [the TensorFlow documentation](https://www.tensorflow.org/programmers_guide/variable_scope#the_problem) to get another look at using `tf.variable_scope`.
#
# #### Leaky ReLU
# TensorFlow doesn't provide an operation for leaky ReLUs, so we'll need to make one . For this you can just take the outputs from a linear fully connected layer and pass them to `tf.maximum`. Typically, a parameter `alpha` sets the magnitude of the output for negative values. So, the output for negative input (`x`) values is `alpha*x`, and the output for positive `x` is `x`:
# $$
# f(x) = max(\alpha * x, x)
# $$
#
# #### Tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output. This means that we'll have to rescale the MNIST images to be between -1 and 1, instead of 0 and 1.
#
# >**Exercise:** Implement the generator network in the function below. You'll need to return the tanh output. Make sure to wrap your code in a variable scope, with 'generator' as the scope name, and pass the `reuse` keyword argument from the function to `tf.variable_scope`.

# %%
def generator(z, out_dim, n_units=128, reuse=False,  alpha=0.01):
    ''' Build the generator network.
    
        Arguments
        ---------
        z : Input tensor for the generator
        out_dim : Shape of the generator output
        n_units : Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out, logits: 
    '''
    with tf.variable_scope('generator', reuse = reuse): # finish this
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation = None)
        # Leaky ReLU
        h1 = tf.maximum(h1, alpha*h1)
        
        # Logits and tanh output
        logits = tf.layers.dense(h1, out_dim, activation = None)
        out = tf.tanh(logits)
        
        return out

# %% [markdown]
# ## Discriminator
#
# The discriminator network is almost exactly the same as the generator network, except that we're using a sigmoid output layer.
#
# >**Exercise:** Implement the discriminator network in the function below. Same as above, you'll need to return both the logits and the sigmoid output. Make sure to wrap your code in a variable scope, with 'discriminator' as the scope name, and pass the `reuse` keyword argument from the function arguments to `tf.variable_scope`.

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    ''' Build the discriminator network.
    
        Arguments
        ---------
        x : Input tensor for the discriminator
        n_units: Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out, logits: 
    '''
    with tf.variable_scope('discriminator', reuse = reuse): # finish this
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation = None)
        # Leaky ReLU
        h1 = tf.maximum(h1, h1*alpha)
        
        logits = tf.layers.dense(h1, 2 )
        out = tf.tanh(logits)
        
        return out, logits

# %% [markdown]
# ## Hyperparameters

# %%
# Size of input image to discriminator
input_size = 784 # 28x28 MNIST images flattened
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 128
d_hidden_size = 128
# Leak factor for leaky ReLU
alpha = 0.01
# Label smoothing 
smooth = 0.1

# %% [markdown]
# ## Build network
#
# Now we're building the network from the functions defined above.
#
# First is to get our inputs, `input_real, input_z` from `model_inputs` using the sizes of the input and z.
#
# Then, we'll create the generator, `generator(input_z, input_size)`. This builds the generator with the appropriate input and output sizes.
#
# Then the discriminators. We'll build two of them, one for real data and one for fake data. Since we want the weights to be the same for both real and fake data, we need to reuse the variables. For the fake data, we're getting it from the generator as `g_model`. So the real data discriminator is `discriminator(input_real)` while the fake discriminator is `discriminator(g_model, reuse=True)`.
#
# >**Exercise:** Build the network from the functions you defined earlier.

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z, inputs_past =  model_inputs([None, input_size], [None, z_size])

# Generator network here
g_model = generator(input_z, input_size, g_hidden_size)
# g_model is the generator output

# Disriminator network here
d_model_real, d_logits_real =  discriminator(input_real, d_hidden_size, alpha = alpha)
d_model_fake, d_logits_fake =  discriminator(g_model, d_hidden_size, reuse=True, alpha = alpha)
#d_model_past, d_logits_past =  discriminator(g_model, d_hidden_size, reuse=True, alpha = alpha)

# %% [markdown]
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses, which is a little tricky. For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_loss_real + d_loss_fake`. The losses will by sigmoid cross-entropies, which we can get with `tf.nn.sigmoid_cross_entropy_with_logits`. We'll also wrap that in `tf.reduce_mean` to get the mean for all the images in the batch. So the losses will look something like
#
# ```python
# tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))
# ```
#
# For the real image logits, we'll use `d_logits_real` which we got from the discriminator in the cell above. For the labels, we want them to be all ones, since these are all real images. To help the discriminator generalize better, the labels are reduced a bit from 1.0 to 0.9, for example,  using the parameter `smooth`. This is known as label smoothing, typically used with classifiers to improve performance. In TensorFlow, it looks something like `labels = tf.ones_like(tensor) * (1 - smooth)`
#
# The discriminator loss for the fake data is similar. The logits are `d_logits_fake`, which we got from passing the generator output to the discriminator. These fake logits are used with labels of all zeros. Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# Finally, the generator losses are using `d_logits_fake`, the fake image logits. But, now the labels are all ones. The generator is trying to fool the discriminator, so it wants to discriminator to output ones for fake images.
#
# >**Exercise:** Calculate the losses for the discriminator and the generator. There are two discriminator losses, one for real images and one for fake images. For the real image loss, use the real logits and (smoothed) labels of ones. For the fake image loss, use the fake logits with labels of all zeros. The total discriminator loss is the sum of those two losses. Finally, the generator loss again uses the fake logits from the discriminator, but this time the labels are all ones because the generator wants to fool the discriminator.

# %%
# Calculate losses
labels_real = tf.one_hot( tf.cast(tf.ones_like(d_logits_real[:,0]),tf.int32),2)* (1 - smooth)
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=labels_real))

labels_real_inverted = tf.one_hot( tf.cast(tf.zeros_like(d_logits_real[:,0]),tf.int32),2)
d_loss_real_inverted = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=labels_real_inverted))

labels_fake = tf.one_hot(tf.cast(tf.zeros_like(d_logits_fake[:,0]),tf.int32),2)
d_loss_fake =  tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=labels_fake))

d_loss = d_loss_real + d_loss_fake
labels_unfake = tf.one_hot(tf.cast(tf.ones_like(d_logits_fake[:,0]), tf.int32),2)
g_loss =  tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=labels_unfake))

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So we need to get the variables for each part and build optimizers for the two parts. To get all the trainable variables, we use `tf.trainable_variables()`. This creates a list of all the variables we've defined in our graph.
#
# For the generator optimizer, we only want to generator variables. Our past selves were nice and used a variable scope to start all of our generator variable names with `generator`. So, we just need to iterate through the list from `tf.trainable_variables()` and keep variables that start with `generator`. Each variable object has an attribute `name` which holds the name of the variable as a string (`var.name == 'weights_0'` for instance).
#
# We can do something similar with the discriminator. All the variables in the discriminator start with `discriminator`.
#
# Then, in the optimizer we pass the variable lists to the `var_list` keyword argument of the `minimize` method. This tells the optimizer to only update the listed variables. Something like `tf.train.AdamOptimizer().minimize(loss, var_list=var_list)` will only train the variables in `var_list`.
#
# >**Exercise: ** Below, implement the optimizers for the generator and discriminator. First you'll need to get a list of trainable variables, then split that list into two lists, one for the generator variables and another for the discriminator variables. Finally, using `AdamOptimizer`, create an optimizer for each network that update the network variables separately.

# %%
# Optimizers
learning_rate = 0.002

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables() 
g_vars = [var for var in t_vars if 'generator' in var.name]
d_vars = [var for var in t_vars if 'discriminator' in var.name]

print([g.name for g in g_vars])
print([d.name for d in d_vars])
d_train_opt =  tf.train.AdamOptimizer().minimize(d_loss, var_list=d_vars) 
g_train_opt = tf.train.AdamOptimizer().minimize(g_loss, var_list=g_vars)
# Out:
# ['generator/dense/kernel:0', 'generator/dense/bias:0', 'generator/dense_1/kernel:0', 'generator/dense_1/bias:0']
# ['discriminator/dense/kernel:0', 'discriminator/dense/bias:0', 'discriminator/dense_1/kernel:0', 'discriminator/dense_1/bias:0']

# %% [markdown]
# ## Training

# %%
batch_size = 100
epochs = 1000
samples = []
all_samples = []
losses = []
saver = tf.train.Saver(var_list = g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d, train_loss_d_real = sess.run([d_loss, d_loss_real], {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    

        
        # Sample from generator as we're training for viewing afterwards
        num_samples = 1000
        sample_z = np.random.uniform(-1, 1, size=(num_samples, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, reuse=True),
                       feed_dict={input_z: sample_z})
        all_samples.append(gen_samples)
        samples.append(gen_samples[:16])
        
        # log the discriminator loss on generated data from 25 epochs ago
        if e > 25: 
            train_loss_d_past25 = sess.run(d_loss_real_inverted, {input_real: all_samples[e-25]})
        else:
            train_loss_d_past25 =0 # just a dummy value

        
                # Save losses to view after training
        losses.append((train_loss_d, train_loss_g, train_loss_d_real, 
                       train_loss_d_past25))
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
with open('losses.pkl', 'wb') as f:
    pkl.dump(losses, f)
# Out:
# Epoch 1/1000... Discriminator Loss: 0.2210... Generator Loss: 3.9825
# Epoch 2/1000... Discriminator Loss: 0.6091... Generator Loss: 2.0402
# Epoch 3/1000... Discriminator Loss: 1.1496... Generator Loss: 2.8638
# Epoch 4/1000... Discriminator Loss: 1.7119... Generator Loss: 3.1818
# Epoch 5/1000... Discriminator Loss: 0.9369... Generator Loss: 3.4115
# Epoch 6/1000... Discriminator Loss: 0.7614... Generator Loss: 3.1951
# Epoch 7/1000... Discriminator Loss: 0.8994... Generator Loss: 1.7289
# Epoch 8/1000... Discriminator Loss: 0.3530... Generator Loss: 4.7949
# Epoch 9/1000... Discriminator Loss: 0.9868... Generator Loss: 2.5214
# Epoch 10/1000... Discriminator Loss: 0.9031... Generator Loss: 4.2166
# Epoch 11/1000... Discriminator Loss: 1.3328... Generator Loss: 2.7916
# Epoch 12/1000... Discriminator Loss: 1.3017... Generator Loss: 1.8942
# Epoch 13/1000... Discriminator Loss: 2.3472... Generator Loss: 2.1234
# Epoch 14/1000... Discriminator Loss: 1.1276... Generator Loss: 2.6180
# Epoch 15/1000... Discriminator Loss: 1.1209... Generator Loss: 2.3903
# Epoch 16/1000... Discriminator Loss: 0.8971... Generator Loss: 3.3765
# Epoch 17/1000... Discriminator Loss: 1.2481... Generator Loss: 2.6241
# Epoch 18/1000... Discriminator Loss: 0.7081... Generator Loss: 2.2900
# Epoch 19/1000... Discriminator Loss: 0.9897... Generator Loss: 1.9397
# Epoch 20/1000... Discriminator Loss: 1.2739... Generator Loss: 1.7403
# Epoch 21/1000... Discriminator Loss: 1.7934... Generator Loss: 1.0048
# Epoch 22/1000... Discriminator Loss: 0.5762... Generator Loss: 2.9283
# Epoch 23/1000... Discriminator Loss: 0.9057... Generator Loss: 1.8751
# Epoch 24/1000... Discriminator Loss: 1.3212... Generator Loss: 1.6959
# Epoch 25/1000... Discriminator Loss: 0.9187... Generator Loss: 1.7480
# Epoch 26/1000... Discriminator Loss: 1.0763... Generator Loss: 2.1354
# Epoch 27/1000... Discriminator Loss: 1.5161... Generator Loss: 1.9672
# Epoch 28/1000... Discriminator Loss: 0.8391... Generator Loss: 2.1049
# Epoch 29/1000... Discriminator Loss: 0.8758... Generator Loss: 2.2602
# Epoch 30/1000... Discriminator Loss: 0.8523... Generator Loss: 2.0285
# Epoch 31/1000... Discriminator Loss: 0.9476... Generator Loss: 1.5182
# Epoch 32/1000... Discriminator Loss: 1.1579... Generator Loss: 1.6126
# Epoch 33/1000... Discriminator Loss: 1.1967... Generator Loss: 1.7349
# Epoch 34/1000... Discriminator Loss: 1.0953... Generator Loss: 2.0905
# Epoch 35/1000... Discriminator Loss: 0.6827... Generator Loss: 2.3876
# Epoch 36/1000... Discriminator Loss: 1.0709... Generator Loss: 1.3128
# Epoch 37/1000... Discriminator Loss: 0.9486... Generator Loss: 2.3892
# Epoch 38/1000... Discriminator Loss: 1.3780... Generator Loss: 1.7831
# Epoch 39/1000... Discriminator Loss: 1.1443... Generator Loss: 1.7504
# Epoch 40/1000... Discriminator Loss: 1.0793... Generator Loss: 1.5113
# Epoch 41/1000... Discriminator Loss: 1.4630... Generator Loss: 1.0943
# Epoch 42/1000... Discriminator Loss: 0.9621... Generator Loss: 1.6757
# Epoch 43/1000... Discriminator Loss: 0.7622... Generator Loss: 2.3934
# Epoch 44/1000... Discriminator Loss: 0.9691... Generator Loss: 2.1932
# Epoch 45/1000... Discriminator Loss: 0.9872... Generator Loss: 2.0457
# Epoch 46/1000... Discriminator Loss: 1.1506... Generator Loss: 1.4979
# Epoch 47/1000... Discriminator Loss: 1.1834... Generator Loss: 1.8369
# Epoch 48/1000... Discriminator Loss: 0.8022... Generator Loss: 1.8462
# Epoch 49/1000... Discriminator Loss: 0.7939... Generator Loss: 2.0125
# Epoch 50/1000... Discriminator Loss: 0.9098... Generator Loss: 2.0314
# Epoch 51/1000... Discriminator Loss: 1.2727... Generator Loss: 1.5642
# Epoch 52/1000... Discriminator Loss: 1.0967... Generator Loss: 1.3961
# Epoch 53/1000... Discriminator Loss: 1.4004... Generator Loss: 1.4469
# Epoch 54/1000... Discriminator Loss: 1.2872... Generator Loss: 1.1297
# Epoch 55/1000... Discriminator Loss: 0.8167... Generator Loss: 1.8583
# Epoch 56/1000... Discriminator Loss: 1.2529... Generator Loss: 1.4637
# Epoch 57/1000... Discriminator Loss: 1.0619... Generator Loss: 1.4582
# Epoch 58/1000... Discriminator Loss: 1.0103... Generator Loss: 1.8808
# Epoch 59/1000... Discriminator Loss: 0.9620... Generator Loss: 1.5734
# Epoch 60/1000... Discriminator Loss: 1.0532... Generator Loss: 1.5722
# Epoch 61/1000... Discriminator Loss: 0.8540... Generator Loss: 1.9909
# Epoch 62/1000... Discriminator Loss: 1.2108... Generator Loss: 1.5360
# Epoch 63/1000... Discriminator Loss: 1.1186... Generator Loss: 1.3531
# Epoch 64/1000... Discriminator Loss: 0.9965... Generator Loss: 1.3551
# Epoch 65/1000... Discriminator Loss: 0.8894... Generator Loss: 1.7529
# Epoch 66/1000... Discriminator Loss: 0.8767... Generator Loss: 1.5604
# Epoch 67/1000... Discriminator Loss: 1.0394... Generator Loss: 1.7135
# Epoch 68/1000... Discriminator Loss: 0.9488... Generator Loss: 1.9005
# Epoch 69/1000... Discriminator Loss: 1.0117... Generator Loss: 1.7516
# Epoch 70/1000... Discriminator Loss: 1.3948... Generator Loss: 1.6435
# Epoch 71/1000... Discriminator Loss: 1.0355... Generator Loss: 1.5242
# Epoch 72/1000... Discriminator Loss: 0.9737... Generator Loss: 1.7386
# Epoch 73/1000... Discriminator Loss: 1.0592... Generator Loss: 1.3585
# Epoch 74/1000... Discriminator Loss: 0.9605... Generator Loss: 1.4319
# Epoch 75/1000... Discriminator Loss: 1.0550... Generator Loss: 1.5787
# Epoch 76/1000... Discriminator Loss: 0.8909... Generator Loss: 1.9261
# Epoch 77/1000... Discriminator Loss: 1.0867... Generator Loss: 1.4835
# Epoch 78/1000... Discriminator Loss: 0.8921... Generator Loss: 2.1141
# Epoch 79/1000... Discriminator Loss: 1.0252... Generator Loss: 1.7370
# Epoch 80/1000... Discriminator Loss: 0.8380... Generator Loss: 2.0145
# Epoch 81/1000... Discriminator Loss: 0.7784... Generator Loss: 1.7291
# Epoch 82/1000... Discriminator Loss: 0.9401... Generator Loss: 1.7828
# Epoch 83/1000... Discriminator Loss: 0.7772... Generator Loss: 2.1575
# Epoch 84/1000... Discriminator Loss: 0.9047... Generator Loss: 1.4036
# Epoch 85/1000... Discriminator Loss: 0.8362... Generator Loss: 1.6492
# Epoch 86/1000... Discriminator Loss: 0.8486... Generator Loss: 1.8432
# Epoch 87/1000... Discriminator Loss: 1.0583... Generator Loss: 1.6169
# Epoch 88/1000... Discriminator Loss: 0.9763... Generator Loss: 1.6793
# Epoch 89/1000... Discriminator Loss: 0.7600... Generator Loss: 2.3942
# Epoch 90/1000... Discriminator Loss: 0.8559... Generator Loss: 1.7077
# Epoch 91/1000... Discriminator Loss: 0.9328... Generator Loss: 1.7927
# Epoch 92/1000... Discriminator Loss: 0.8687... Generator Loss: 1.7427
# Epoch 93/1000... Discriminator Loss: 1.0235... Generator Loss: 2.1918
# Epoch 94/1000... Discriminator Loss: 0.7770... Generator Loss: 2.3621
# Epoch 95/1000... Discriminator Loss: 0.8995... Generator Loss: 1.8124
# Epoch 96/1000... Discriminator Loss: 0.9476... Generator Loss: 2.0158
# Epoch 97/1000... Discriminator Loss: 0.9310... Generator Loss: 1.6638
# Epoch 98/1000... Discriminator Loss: 0.8976... Generator Loss: 1.8933
# Epoch 99/1000... Discriminator Loss: 0.8915... Generator Loss: 1.6513
# Epoch 100/1000... Discriminator Loss: 1.0075... Generator Loss: 1.9755
# Epoch 101/1000... Discriminator Loss: 0.9956... Generator Loss: 1.8174
# Epoch 102/1000... Discriminator Loss: 0.9479... Generator Loss: 1.8886
# Epoch 103/1000... Discriminator Loss: 1.0521... Generator Loss: 1.7514
# Epoch 104/1000... Discriminator Loss: 0.8292... Generator Loss: 1.6031
# Epoch 105/1000... Discriminator Loss: 0.9718... Generator Loss: 2.0903
# Epoch 106/1000... Discriminator Loss: 0.9325... Generator Loss: 1.7473
# Epoch 107/1000... Discriminator Loss: 0.9635... Generator Loss: 2.0111
# Epoch 108/1000... Discriminator Loss: 0.9182... Generator Loss: 1.8239
# Epoch 109/1000... Discriminator Loss: 0.9675... Generator Loss: 1.3338
# Epoch 110/1000... Discriminator Loss: 0.9371... Generator Loss: 1.5504
# Epoch 111/1000... Discriminator Loss: 1.0520... Generator Loss: 1.5563
# Epoch 112/1000... Discriminator Loss: 1.1177... Generator Loss: 1.3362
# Epoch 113/1000... Discriminator Loss: 0.8156... Generator Loss: 1.5250
# Epoch 114/1000... Discriminator Loss: 1.0710... Generator Loss: 1.2358
# Epoch 115/1000... Discriminator Loss: 0.9438... Generator Loss: 1.7610
# Epoch 116/1000... Discriminator Loss: 0.8950... Generator Loss: 1.7339
# Epoch 117/1000... Discriminator Loss: 0.8617... Generator Loss: 1.8680
# Epoch 118/1000... Discriminator Loss: 0.9466... Generator Loss: 2.0856
# Epoch 119/1000... Discriminator Loss: 1.1755... Generator Loss: 1.4215
# Epoch 120/1000... Discriminator Loss: 0.9659... Generator Loss: 1.6217
# Epoch 121/1000... Discriminator Loss: 0.9032... Generator Loss: 1.3946
# Epoch 122/1000... Discriminator Loss: 0.8600... Generator Loss: 1.6802
# Epoch 123/1000... Discriminator Loss: 0.8455... Generator Loss: 1.9302
# Epoch 124/1000... Discriminator Loss: 1.1901... Generator Loss: 1.5266
# Epoch 125/1000... Discriminator Loss: 0.9929... Generator Loss: 1.5589
# Epoch 126/1000... Discriminator Loss: 0.9038... Generator Loss: 1.7694
# Epoch 127/1000... Discriminator Loss: 1.1195... Generator Loss: 1.5226
# Epoch 128/1000... Discriminator Loss: 0.9269... Generator Loss: 1.6755
# Epoch 129/1000... Discriminator Loss: 1.1445... Generator Loss: 1.5466
# Epoch 130/1000... Discriminator Loss: 1.0739... Generator Loss: 1.5783
# Epoch 131/1000... Discriminator Loss: 0.9936... Generator Loss: 1.4707
# Epoch 132/1000... Discriminator Loss: 0.8416... Generator Loss: 1.5959
# Epoch 133/1000... Discriminator Loss: 1.2726... Generator Loss: 1.8746
# Epoch 134/1000... Discriminator Loss: 0.9545... Generator Loss: 1.6642
# Epoch 135/1000... Discriminator Loss: 0.9402... Generator Loss: 1.4760
# Epoch 136/1000... Discriminator Loss: 0.9717... Generator Loss: 1.7596
# Epoch 137/1000... Discriminator Loss: 0.9213... Generator Loss: 1.9418
# Epoch 138/1000... Discriminator Loss: 0.8567... Generator Loss: 1.8465
# Epoch 139/1000... Discriminator Loss: 1.1762... Generator Loss: 1.4438
# Epoch 140/1000... Discriminator Loss: 1.0367... Generator Loss: 1.3895
# Epoch 141/1000... Discriminator Loss: 0.8685... Generator Loss: 1.8095
# Epoch 142/1000... Discriminator Loss: 0.8906... Generator Loss: 1.7554
# Epoch 143/1000... Discriminator Loss: 0.9887... Generator Loss: 1.5586
# Epoch 144/1000... Discriminator Loss: 0.9859... Generator Loss: 1.6226
# Epoch 145/1000... Discriminator Loss: 1.0598... Generator Loss: 1.6697
# Epoch 146/1000... Discriminator Loss: 0.8895... Generator Loss: 2.1873
# Epoch 147/1000... Discriminator Loss: 1.0568... Generator Loss: 1.9912
# Epoch 148/1000... Discriminator Loss: 0.8925... Generator Loss: 1.9003
# Epoch 149/1000... Discriminator Loss: 0.9847... Generator Loss: 1.9218
# Epoch 150/1000... Discriminator Loss: 1.0003... Generator Loss: 1.7127
# Epoch 151/1000... Discriminator Loss: 1.2447... Generator Loss: 1.0341
# Epoch 152/1000... Discriminator Loss: 1.0219... Generator Loss: 1.4096
# Epoch 153/1000... Discriminator Loss: 0.8580... Generator Loss: 1.8267
# Epoch 154/1000... Discriminator Loss: 0.9189... Generator Loss: 1.7358
# Epoch 155/1000... Discriminator Loss: 0.9614... Generator Loss: 1.6879
# Epoch 156/1000... Discriminator Loss: 1.1172... Generator Loss: 1.4393
# Epoch 157/1000... Discriminator Loss: 0.8662... Generator Loss: 1.6718
# Epoch 158/1000... Discriminator Loss: 0.9681... Generator Loss: 1.5177
# Epoch 159/1000... Discriminator Loss: 1.0949... Generator Loss: 1.6165
# Epoch 160/1000... Discriminator Loss: 1.1541... Generator Loss: 1.5350
# Epoch 161/1000... Discriminator Loss: 1.1323... Generator Loss: 1.5509
# Epoch 162/1000... Discriminator Loss: 1.0046... Generator Loss: 1.8205
# Epoch 163/1000... Discriminator Loss: 0.9154... Generator Loss: 1.4640
# Epoch 164/1000... Discriminator Loss: 0.9952... Generator Loss: 1.7036
# Epoch 165/1000... Discriminator Loss: 0.9947... Generator Loss: 1.4052
# Epoch 166/1000... Discriminator Loss: 0.8877... Generator Loss: 1.7178
# Epoch 167/1000... Discriminator Loss: 0.9224... Generator Loss: 1.5334
# Epoch 168/1000... Discriminator Loss: 0.9151... Generator Loss: 1.4472
# Epoch 169/1000... Discriminator Loss: 0.9042... Generator Loss: 1.7651
# Epoch 170/1000... Discriminator Loss: 0.9239... Generator Loss: 1.9339
# Epoch 171/1000... Discriminator Loss: 1.1188... Generator Loss: 1.1777
# Epoch 172/1000... Discriminator Loss: 0.9747... Generator Loss: 1.8417
# Epoch 173/1000... Discriminator Loss: 0.8808... Generator Loss: 1.7518
# Epoch 174/1000... Discriminator Loss: 0.9614... Generator Loss: 1.6374
# Epoch 175/1000... Discriminator Loss: 0.9225... Generator Loss: 1.7217
# Epoch 176/1000... Discriminator Loss: 1.0559... Generator Loss: 1.4321
# Epoch 177/1000... Discriminator Loss: 0.9380... Generator Loss: 1.4109
# Epoch 178/1000... Discriminator Loss: 0.9668... Generator Loss: 1.6463
# Epoch 179/1000... Discriminator Loss: 1.1423... Generator Loss: 1.3696
# Epoch 180/1000... Discriminator Loss: 0.9582... Generator Loss: 1.8990
# Epoch 181/1000... Discriminator Loss: 0.9779... Generator Loss: 1.5609
# Epoch 182/1000... Discriminator Loss: 1.0851... Generator Loss: 1.6474
# Epoch 183/1000... Discriminator Loss: 0.8589... Generator Loss: 1.7553
# Epoch 184/1000... Discriminator Loss: 0.9357... Generator Loss: 1.9060
# Epoch 185/1000... Discriminator Loss: 1.0727... Generator Loss: 1.5161
# Epoch 186/1000... Discriminator Loss: 0.8686... Generator Loss: 1.8080
# Epoch 187/1000... Discriminator Loss: 0.9488... Generator Loss: 1.5160
# Epoch 188/1000... Discriminator Loss: 0.8073... Generator Loss: 1.8617
# Epoch 189/1000... Discriminator Loss: 1.0439... Generator Loss: 1.5312
# Epoch 190/1000... Discriminator Loss: 0.9873... Generator Loss: 1.5283
# Epoch 191/1000... Discriminator Loss: 1.2156... Generator Loss: 1.4766
# Epoch 192/1000... Discriminator Loss: 0.8587... Generator Loss: 1.7032
# Epoch 193/1000... Discriminator Loss: 1.0408... Generator Loss: 1.3716
# Epoch 194/1000... Discriminator Loss: 0.9318... Generator Loss: 1.6683
# Epoch 195/1000... Discriminator Loss: 0.9809... Generator Loss: 1.7528
# Epoch 196/1000... Discriminator Loss: 0.9483... Generator Loss: 1.8195
# Epoch 197/1000... Discriminator Loss: 0.8584... Generator Loss: 1.6880
# Epoch 198/1000... Discriminator Loss: 0.8351... Generator Loss: 1.6459
# Epoch 199/1000... Discriminator Loss: 1.0940... Generator Loss: 1.3833
# Epoch 200/1000... Discriminator Loss: 1.1445... Generator Loss: 1.3988
# Epoch 201/1000... Discriminator Loss: 0.9302... Generator Loss: 1.5527
# Epoch 202/1000... Discriminator Loss: 1.0449... Generator Loss: 1.6231
# Epoch 203/1000... Discriminator Loss: 0.9784... Generator Loss: 1.7326
# Epoch 204/1000... Discriminator Loss: 1.1058... Generator Loss: 1.7341
# Epoch 205/1000... Discriminator Loss: 0.9319... Generator Loss: 1.5709
# Epoch 206/1000... Discriminator Loss: 1.0858... Generator Loss: 1.3648
# Epoch 207/1000... Discriminator Loss: 1.0134... Generator Loss: 1.5274
# Epoch 208/1000... Discriminator Loss: 0.9132... Generator Loss: 1.4994
# Epoch 209/1000... Discriminator Loss: 0.9880... Generator Loss: 1.7331
# Epoch 210/1000... Discriminator Loss: 1.0135... Generator Loss: 1.5202
# Epoch 211/1000... Discriminator Loss: 1.0109... Generator Loss: 1.7921
# Epoch 212/1000... Discriminator Loss: 0.9487... Generator Loss: 1.4494
# Epoch 213/1000... Discriminator Loss: 0.7835... Generator Loss: 2.3897
# Epoch 214/1000... Discriminator Loss: 0.9781... Generator Loss: 1.7302
# Epoch 215/1000... Discriminator Loss: 0.9141... Generator Loss: 1.5551
# Epoch 216/1000... Discriminator Loss: 0.9964... Generator Loss: 1.6096
# Epoch 217/1000... Discriminator Loss: 1.0814... Generator Loss: 1.3666
# Epoch 218/1000... Discriminator Loss: 0.9015... Generator Loss: 1.7630
# Epoch 219/1000... Discriminator Loss: 0.9712... Generator Loss: 1.5632
# Epoch 220/1000... Discriminator Loss: 0.9183... Generator Loss: 1.6445
# Epoch 221/1000... Discriminator Loss: 0.8839... Generator Loss: 1.7383
# Epoch 222/1000... Discriminator Loss: 0.9630... Generator Loss: 1.6739
# Epoch 223/1000... Discriminator Loss: 0.9730... Generator Loss: 1.7197
# Epoch 224/1000... Discriminator Loss: 1.0832... Generator Loss: 1.5327
# Epoch 225/1000... Discriminator Loss: 0.9190... Generator Loss: 1.9015
# Epoch 226/1000... Discriminator Loss: 0.9153... Generator Loss: 1.7281
# Epoch 227/1000... Discriminator Loss: 1.0238... Generator Loss: 1.8126
# Epoch 228/1000... Discriminator Loss: 0.8837... Generator Loss: 1.5815
# Epoch 229/1000... Discriminator Loss: 0.9394... Generator Loss: 1.5349
# Epoch 230/1000... Discriminator Loss: 0.9690... Generator Loss: 1.4449
# Epoch 231/1000... Discriminator Loss: 1.0126... Generator Loss: 1.7768
# Epoch 232/1000... Discriminator Loss: 1.0105... Generator Loss: 1.7523
# Epoch 233/1000... Discriminator Loss: 0.9915... Generator Loss: 1.7087
# Epoch 234/1000... Discriminator Loss: 0.9806... Generator Loss: 1.5401
# Epoch 235/1000... Discriminator Loss: 1.0049... Generator Loss: 1.7896
# Epoch 236/1000... Discriminator Loss: 0.9580... Generator Loss: 1.6748
# Epoch 237/1000... Discriminator Loss: 1.0296... Generator Loss: 1.8926
# Epoch 238/1000... Discriminator Loss: 0.9880... Generator Loss: 1.6869
# Epoch 239/1000... Discriminator Loss: 1.1485... Generator Loss: 1.4866
# Epoch 240/1000... Discriminator Loss: 0.9500... Generator Loss: 1.4854
# Epoch 241/1000... Discriminator Loss: 0.9633... Generator Loss: 1.6117
# Epoch 242/1000... Discriminator Loss: 1.0086... Generator Loss: 1.3974
# Epoch 243/1000... Discriminator Loss: 0.9512... Generator Loss: 1.7408
# Epoch 244/1000... Discriminator Loss: 0.9487... Generator Loss: 1.7677
# Epoch 245/1000... Discriminator Loss: 0.9647... Generator Loss: 1.5777
# Epoch 246/1000... Discriminator Loss: 1.0041... Generator Loss: 1.4589
# Epoch 247/1000... Discriminator Loss: 1.0349... Generator Loss: 1.5232
# Epoch 248/1000... Discriminator Loss: 0.9169... Generator Loss: 1.9079
# Epoch 249/1000... Discriminator Loss: 0.9227... Generator Loss: 1.4322
# Epoch 250/1000... Discriminator Loss: 1.0312... Generator Loss: 1.6832
# Epoch 251/1000... Discriminator Loss: 0.9152... Generator Loss: 1.7331
# Epoch 252/1000... Discriminator Loss: 0.9327... Generator Loss: 1.6547
# Epoch 253/1000... Discriminator Loss: 0.9209... Generator Loss: 1.7985
# Epoch 254/1000... Discriminator Loss: 0.8652... Generator Loss: 1.6044
# Epoch 255/1000... Discriminator Loss: 0.9773... Generator Loss: 1.5232
# Epoch 256/1000... Discriminator Loss: 1.0664... Generator Loss: 1.6032
# Epoch 257/1000... Discriminator Loss: 1.0435... Generator Loss: 1.5001
# Epoch 258/1000... Discriminator Loss: 0.9680... Generator Loss: 1.5442
# Epoch 259/1000... Discriminator Loss: 0.8466... Generator Loss: 1.7583
# Epoch 260/1000... Discriminator Loss: 0.8074... Generator Loss: 1.9229
# Epoch 261/1000... Discriminator Loss: 0.8383... Generator Loss: 1.8275
# Epoch 262/1000... Discriminator Loss: 0.9686... Generator Loss: 1.4795
# Epoch 263/1000... Discriminator Loss: 1.0972... Generator Loss: 1.5416
# Epoch 264/1000... Discriminator Loss: 1.0532... Generator Loss: 1.7521
# Epoch 265/1000... Discriminator Loss: 0.8361... Generator Loss: 1.8737
# Epoch 266/1000... Discriminator Loss: 1.0490... Generator Loss: 1.4988
# Epoch 267/1000... Discriminator Loss: 0.8023... Generator Loss: 1.7874
# Epoch 268/1000... Discriminator Loss: 0.9678... Generator Loss: 1.8722
# Epoch 269/1000... Discriminator Loss: 0.8874... Generator Loss: 1.8934
# Epoch 270/1000... Discriminator Loss: 1.0371... Generator Loss: 1.4281
# Epoch 271/1000... Discriminator Loss: 0.9961... Generator Loss: 1.7540
# Epoch 272/1000... Discriminator Loss: 0.9525... Generator Loss: 1.5999
# Epoch 273/1000... Discriminator Loss: 0.8803... Generator Loss: 1.6616
# Epoch 274/1000... Discriminator Loss: 0.9239... Generator Loss: 1.3463
# Epoch 275/1000... Discriminator Loss: 0.9119... Generator Loss: 1.7374
# Epoch 276/1000... Discriminator Loss: 0.9517... Generator Loss: 1.7855
# Epoch 277/1000... Discriminator Loss: 0.9975... Generator Loss: 1.4684
# Epoch 278/1000... Discriminator Loss: 0.9060... Generator Loss: 1.6900
# Epoch 279/1000... Discriminator Loss: 0.8953... Generator Loss: 1.7167
# Epoch 280/1000... Discriminator Loss: 0.9559... Generator Loss: 1.5332
# Epoch 281/1000... Discriminator Loss: 1.0332... Generator Loss: 1.4830
# Epoch 282/1000... Discriminator Loss: 1.0176... Generator Loss: 1.4270
# Epoch 283/1000... Discriminator Loss: 0.9393... Generator Loss: 1.5121
# Epoch 284/1000... Discriminator Loss: 1.0392... Generator Loss: 1.3667
# Epoch 285/1000... Discriminator Loss: 0.9394... Generator Loss: 1.7363
# Epoch 286/1000... Discriminator Loss: 0.8675... Generator Loss: 1.3692
# Epoch 287/1000... Discriminator Loss: 1.0495... Generator Loss: 1.4711
# Epoch 288/1000... Discriminator Loss: 0.8294... Generator Loss: 1.7231
# Epoch 289/1000... Discriminator Loss: 1.0231... Generator Loss: 1.6844
# Epoch 290/1000... Discriminator Loss: 1.0717... Generator Loss: 1.3845
# Epoch 291/1000... Discriminator Loss: 0.8979... Generator Loss: 1.4117
# Epoch 292/1000... Discriminator Loss: 0.8959... Generator Loss: 1.6417
# Epoch 293/1000... Discriminator Loss: 1.0801... Generator Loss: 1.6351
# Epoch 294/1000... Discriminator Loss: 0.8716... Generator Loss: 1.5987
# Epoch 295/1000... Discriminator Loss: 0.9491... Generator Loss: 1.5533
# Epoch 296/1000... Discriminator Loss: 0.9352... Generator Loss: 1.7811
# Epoch 297/1000... Discriminator Loss: 1.0429... Generator Loss: 1.5312
# Epoch 298/1000... Discriminator Loss: 0.9199... Generator Loss: 1.6122
# Epoch 299/1000... Discriminator Loss: 1.0117... Generator Loss: 1.7426
# Epoch 300/1000... Discriminator Loss: 0.9091... Generator Loss: 1.7442
# Epoch 301/1000... Discriminator Loss: 0.9555... Generator Loss: 1.8329
# Epoch 302/1000... Discriminator Loss: 1.0935... Generator Loss: 1.5228
# Epoch 303/1000... Discriminator Loss: 0.9074... Generator Loss: 1.6814
# Epoch 304/1000... Discriminator Loss: 0.8661... Generator Loss: 1.5516
# Epoch 305/1000... Discriminator Loss: 0.9350... Generator Loss: 1.7067
# Epoch 306/1000... Discriminator Loss: 1.1476... Generator Loss: 1.2321
# Epoch 307/1000... Discriminator Loss: 0.9303... Generator Loss: 1.7031
# Epoch 308/1000... Discriminator Loss: 0.8686... Generator Loss: 1.5626
# Epoch 309/1000... Discriminator Loss: 1.0400... Generator Loss: 1.6133
# Epoch 310/1000... Discriminator Loss: 0.8595... Generator Loss: 1.6935
# Epoch 311/1000... Discriminator Loss: 1.0285... Generator Loss: 1.8242
# Epoch 312/1000... Discriminator Loss: 1.0028... Generator Loss: 1.7451
# Epoch 313/1000... Discriminator Loss: 0.9975... Generator Loss: 1.4277
# Epoch 314/1000... Discriminator Loss: 0.9558... Generator Loss: 2.0402
# Epoch 315/1000... Discriminator Loss: 0.9195... Generator Loss: 1.7526
# Epoch 316/1000... Discriminator Loss: 0.9079... Generator Loss: 1.7508
# Epoch 317/1000... Discriminator Loss: 0.9376... Generator Loss: 1.8434
# Epoch 318/1000... Discriminator Loss: 0.9482... Generator Loss: 1.7750
# Epoch 319/1000... Discriminator Loss: 0.9069... Generator Loss: 1.6323
# Epoch 320/1000... Discriminator Loss: 0.7732... Generator Loss: 1.8128
# Epoch 321/1000... Discriminator Loss: 1.0038... Generator Loss: 1.6210
# Epoch 322/1000... Discriminator Loss: 0.9112... Generator Loss: 1.5612
# Epoch 323/1000... Discriminator Loss: 0.9202... Generator Loss: 1.6597
# Epoch 324/1000... Discriminator Loss: 0.9651... Generator Loss: 1.4516
# Epoch 325/1000... Discriminator Loss: 0.8489... Generator Loss: 2.4118
# Epoch 326/1000... Discriminator Loss: 0.9295... Generator Loss: 1.6928
# Epoch 327/1000... Discriminator Loss: 0.9411... Generator Loss: 1.6557
# Epoch 328/1000... Discriminator Loss: 0.9573... Generator Loss: 1.7349
# Epoch 329/1000... Discriminator Loss: 0.7817... Generator Loss: 1.9759
# Epoch 330/1000... Discriminator Loss: 0.9994... Generator Loss: 1.9201
# Epoch 331/1000... Discriminator Loss: 1.0616... Generator Loss: 1.4466
# Epoch 332/1000... Discriminator Loss: 0.9879... Generator Loss: 1.3840
# Epoch 333/1000... Discriminator Loss: 0.9649... Generator Loss: 2.0767
# Epoch 334/1000... Discriminator Loss: 0.8461... Generator Loss: 1.7871
# Epoch 335/1000... Discriminator Loss: 0.9659... Generator Loss: 1.3858
# Epoch 336/1000... Discriminator Loss: 0.9318... Generator Loss: 1.6567
# Epoch 337/1000... Discriminator Loss: 0.9451... Generator Loss: 1.8243
# Epoch 338/1000... Discriminator Loss: 1.1299... Generator Loss: 1.6236
# Epoch 339/1000... Discriminator Loss: 0.9723... Generator Loss: 1.6126
# Epoch 340/1000... Discriminator Loss: 0.7802... Generator Loss: 1.8435
# Epoch 341/1000... Discriminator Loss: 0.9160... Generator Loss: 1.7879
# Epoch 342/1000... Discriminator Loss: 1.0607... Generator Loss: 1.6099
# Epoch 343/1000... Discriminator Loss: 0.9299... Generator Loss: 1.5528
# Epoch 344/1000... Discriminator Loss: 0.9256... Generator Loss: 1.5400
# Epoch 345/1000... Discriminator Loss: 0.9315... Generator Loss: 1.6152
# Epoch 346/1000... Discriminator Loss: 1.0236... Generator Loss: 1.6653
# Epoch 347/1000... Discriminator Loss: 0.8867... Generator Loss: 1.9702
# Epoch 348/1000... Discriminator Loss: 0.9882... Generator Loss: 1.8017
# Epoch 349/1000... Discriminator Loss: 0.9594... Generator Loss: 1.4252
# Epoch 350/1000... Discriminator Loss: 0.9695... Generator Loss: 1.8510
# Epoch 351/1000... Discriminator Loss: 1.0771... Generator Loss: 1.4153
# Epoch 352/1000... Discriminator Loss: 0.9107... Generator Loss: 1.7730
# Epoch 353/1000... Discriminator Loss: 0.9198... Generator Loss: 1.7607
# Epoch 354/1000... Discriminator Loss: 1.0747... Generator Loss: 1.5798
# Epoch 355/1000... Discriminator Loss: 0.9946... Generator Loss: 1.5573
# Epoch 356/1000... Discriminator Loss: 0.8630... Generator Loss: 1.7230
# Epoch 357/1000... Discriminator Loss: 0.9397... Generator Loss: 1.9451
# Epoch 358/1000... Discriminator Loss: 0.8889... Generator Loss: 1.6684
# Epoch 359/1000... Discriminator Loss: 0.9149... Generator Loss: 1.9537
# Epoch 360/1000... Discriminator Loss: 0.8351... Generator Loss: 1.8381
# Epoch 361/1000... Discriminator Loss: 1.0556... Generator Loss: 1.7281
# Epoch 362/1000... Discriminator Loss: 0.9483... Generator Loss: 1.9571
# Epoch 363/1000... Discriminator Loss: 0.8232... Generator Loss: 1.9510
# Epoch 364/1000... Discriminator Loss: 0.9849... Generator Loss: 1.4972
# Epoch 365/1000... Discriminator Loss: 0.9202... Generator Loss: 1.3871
# Epoch 366/1000... Discriminator Loss: 1.0200... Generator Loss: 1.4311
# Epoch 367/1000... Discriminator Loss: 0.8995... Generator Loss: 1.7133
# Epoch 368/1000... Discriminator Loss: 0.8995... Generator Loss: 1.4825
# Epoch 369/1000... Discriminator Loss: 0.9520... Generator Loss: 1.7817
# Epoch 370/1000... Discriminator Loss: 0.9858... Generator Loss: 1.6405
# Epoch 371/1000... Discriminator Loss: 0.9368... Generator Loss: 1.8982
# Epoch 372/1000... Discriminator Loss: 0.9417... Generator Loss: 2.0598
# Epoch 373/1000... Discriminator Loss: 0.8746... Generator Loss: 1.6783
# Epoch 374/1000... Discriminator Loss: 0.7942... Generator Loss: 1.7246
# Epoch 375/1000... Discriminator Loss: 0.9273... Generator Loss: 1.4479
# Epoch 376/1000... Discriminator Loss: 0.8654... Generator Loss: 1.7222
# Epoch 377/1000... Discriminator Loss: 1.0286... Generator Loss: 1.9400
# Epoch 378/1000... Discriminator Loss: 0.9750... Generator Loss: 2.1721
# Epoch 379/1000... Discriminator Loss: 0.8763... Generator Loss: 1.8132
# Epoch 380/1000... Discriminator Loss: 1.0744... Generator Loss: 2.1160
# Epoch 381/1000... Discriminator Loss: 0.8671... Generator Loss: 1.8821
# Epoch 382/1000... Discriminator Loss: 0.9593... Generator Loss: 1.7049
# Epoch 383/1000... Discriminator Loss: 0.8425... Generator Loss: 2.0104
# Epoch 384/1000... Discriminator Loss: 1.0416... Generator Loss: 1.5367
# Epoch 385/1000... Discriminator Loss: 0.8685... Generator Loss: 1.6754
# Epoch 386/1000... Discriminator Loss: 1.0250... Generator Loss: 1.5450
# Epoch 387/1000... Discriminator Loss: 1.0087... Generator Loss: 1.6124
# Epoch 388/1000... Discriminator Loss: 0.9676... Generator Loss: 1.8446
# Epoch 389/1000... Discriminator Loss: 0.9647... Generator Loss: 1.5330
# Epoch 390/1000... Discriminator Loss: 0.9661... Generator Loss: 1.8268
# Epoch 391/1000... Discriminator Loss: 0.9297... Generator Loss: 1.7555
# Epoch 392/1000... Discriminator Loss: 0.9044... Generator Loss: 1.7069
# Epoch 393/1000... Discriminator Loss: 0.9736... Generator Loss: 1.6538
# Epoch 394/1000... Discriminator Loss: 0.9548... Generator Loss: 2.4395
# Epoch 395/1000... Discriminator Loss: 0.9353... Generator Loss: 1.8229
# Epoch 396/1000... Discriminator Loss: 0.9607... Generator Loss: 1.8275
# Epoch 397/1000... Discriminator Loss: 1.0208... Generator Loss: 1.6335
# Epoch 398/1000... Discriminator Loss: 1.0282... Generator Loss: 2.3210
# Epoch 399/1000... Discriminator Loss: 0.9099... Generator Loss: 1.8929
# Epoch 400/1000... Discriminator Loss: 0.9844... Generator Loss: 2.0274
# Epoch 401/1000... Discriminator Loss: 1.0110... Generator Loss: 1.8670
# Epoch 402/1000... Discriminator Loss: 0.8979... Generator Loss: 1.5282
# Epoch 403/1000... Discriminator Loss: 0.8803... Generator Loss: 2.0422
# Epoch 404/1000... Discriminator Loss: 0.9123... Generator Loss: 1.8378
# Epoch 405/1000... Discriminator Loss: 1.0497... Generator Loss: 1.6805
# Epoch 406/1000... Discriminator Loss: 1.0453... Generator Loss: 1.8905
# Epoch 407/1000... Discriminator Loss: 0.9577... Generator Loss: 1.6229
# Epoch 408/1000... Discriminator Loss: 0.9428... Generator Loss: 2.0194
# Epoch 409/1000... Discriminator Loss: 0.8490... Generator Loss: 1.8883
# Epoch 410/1000... Discriminator Loss: 0.9226... Generator Loss: 1.7522
# Epoch 411/1000... Discriminator Loss: 0.9903... Generator Loss: 1.7413
# Epoch 412/1000... Discriminator Loss: 0.9100... Generator Loss: 1.5603
# Epoch 413/1000... Discriminator Loss: 0.8747... Generator Loss: 2.0258
# Epoch 414/1000... Discriminator Loss: 1.0035... Generator Loss: 1.5924
# Epoch 415/1000... Discriminator Loss: 0.9292... Generator Loss: 1.4565
# Epoch 416/1000... Discriminator Loss: 0.9263... Generator Loss: 1.9429
# Epoch 417/1000... Discriminator Loss: 0.8890... Generator Loss: 1.7636
# Epoch 418/1000... Discriminator Loss: 1.0167... Generator Loss: 1.4495
# Epoch 419/1000... Discriminator Loss: 0.8880... Generator Loss: 1.5004
# Epoch 420/1000... Discriminator Loss: 0.9654... Generator Loss: 1.7185
# Epoch 421/1000... Discriminator Loss: 0.8634... Generator Loss: 1.7545
# Epoch 422/1000... Discriminator Loss: 0.7688... Generator Loss: 1.9820
# Epoch 423/1000... Discriminator Loss: 0.8988... Generator Loss: 2.1021
# Epoch 424/1000... Discriminator Loss: 0.8370... Generator Loss: 1.8777
# Epoch 425/1000... Discriminator Loss: 0.8473... Generator Loss: 1.9433
# Epoch 426/1000... Discriminator Loss: 0.9797... Generator Loss: 1.5038
# Epoch 427/1000... Discriminator Loss: 1.0689... Generator Loss: 1.8434
# Epoch 428/1000... Discriminator Loss: 0.8965... Generator Loss: 1.7212
# Epoch 429/1000... Discriminator Loss: 0.9749... Generator Loss: 1.5036
# Epoch 430/1000... Discriminator Loss: 0.9350... Generator Loss: 1.7202
# Epoch 431/1000... Discriminator Loss: 1.1730... Generator Loss: 1.4931
# Epoch 432/1000... Discriminator Loss: 0.8996... Generator Loss: 1.9432
# Epoch 433/1000... Discriminator Loss: 0.9268... Generator Loss: 2.1572
# Epoch 434/1000... Discriminator Loss: 0.8489... Generator Loss: 1.8687
# Epoch 435/1000... Discriminator Loss: 1.0598... Generator Loss: 1.6696
# Epoch 436/1000... Discriminator Loss: 1.0125... Generator Loss: 1.8482
# Epoch 437/1000... Discriminator Loss: 0.9674... Generator Loss: 1.5142
# Epoch 438/1000... Discriminator Loss: 0.9008... Generator Loss: 1.8163
# Epoch 439/1000... Discriminator Loss: 0.8984... Generator Loss: 1.8137
# Epoch 440/1000... Discriminator Loss: 1.0242... Generator Loss: 1.5167
# Epoch 441/1000... Discriminator Loss: 1.0374... Generator Loss: 1.7981
# Epoch 442/1000... Discriminator Loss: 0.8582... Generator Loss: 1.4741
# Epoch 443/1000... Discriminator Loss: 0.9320... Generator Loss: 1.5402
# Epoch 444/1000... Discriminator Loss: 0.8537... Generator Loss: 1.5131
# Epoch 445/1000... Discriminator Loss: 0.9593... Generator Loss: 1.6212
# Epoch 446/1000... Discriminator Loss: 0.9648... Generator Loss: 1.7556
# Epoch 447/1000... Discriminator Loss: 0.9598... Generator Loss: 1.8952
# Epoch 448/1000... Discriminator Loss: 0.9202... Generator Loss: 1.5209
# Epoch 449/1000... Discriminator Loss: 0.8302... Generator Loss: 1.8962
# Epoch 450/1000... Discriminator Loss: 0.9957... Generator Loss: 2.0176
# Epoch 451/1000... Discriminator Loss: 0.9396... Generator Loss: 2.1965
# Epoch 452/1000... Discriminator Loss: 0.7958... Generator Loss: 1.9023
# Epoch 453/1000... Discriminator Loss: 0.8535... Generator Loss: 1.7402
# Epoch 454/1000... Discriminator Loss: 0.9376... Generator Loss: 1.7493
# Epoch 455/1000... Discriminator Loss: 1.1201... Generator Loss: 1.2757
# Epoch 456/1000... Discriminator Loss: 1.1129... Generator Loss: 1.6309
# Epoch 457/1000... Discriminator Loss: 0.8116... Generator Loss: 2.1043
# Epoch 458/1000... Discriminator Loss: 0.9868... Generator Loss: 1.9901
# Epoch 459/1000... Discriminator Loss: 1.0372... Generator Loss: 1.4033
# Epoch 460/1000... Discriminator Loss: 0.9359... Generator Loss: 2.1340
# Epoch 461/1000... Discriminator Loss: 0.9492... Generator Loss: 1.7349
# Epoch 462/1000... Discriminator Loss: 1.0418... Generator Loss: 1.6278
# Epoch 463/1000... Discriminator Loss: 0.8463... Generator Loss: 2.0193
# Epoch 464/1000... Discriminator Loss: 1.0077... Generator Loss: 2.0139
# Epoch 465/1000... Discriminator Loss: 0.9286... Generator Loss: 1.8675
# Epoch 466/1000... Discriminator Loss: 0.9761... Generator Loss: 1.9521
# Epoch 467/1000... Discriminator Loss: 1.0117... Generator Loss: 1.5646
# Epoch 468/1000... Discriminator Loss: 0.9643... Generator Loss: 1.8432
# Epoch 469/1000... Discriminator Loss: 0.9080... Generator Loss: 1.8382
# Epoch 470/1000... Discriminator Loss: 0.9484... Generator Loss: 1.5080
# Epoch 471/1000... Discriminator Loss: 0.8916... Generator Loss: 1.7853
# Epoch 472/1000... Discriminator Loss: 0.9935... Generator Loss: 1.6855
# Epoch 473/1000... Discriminator Loss: 0.9560... Generator Loss: 1.9432
# Epoch 474/1000... Discriminator Loss: 0.9762... Generator Loss: 1.9112
# Epoch 475/1000... Discriminator Loss: 0.9592... Generator Loss: 1.7110
# Epoch 476/1000... Discriminator Loss: 0.8796... Generator Loss: 1.8800
# Epoch 477/1000... Discriminator Loss: 1.1339... Generator Loss: 1.5553
# Epoch 478/1000... Discriminator Loss: 0.8774... Generator Loss: 1.9422
# Epoch 479/1000... Discriminator Loss: 0.8449... Generator Loss: 1.6150
# Epoch 480/1000... Discriminator Loss: 0.9816... Generator Loss: 1.6932
# Epoch 481/1000... Discriminator Loss: 0.7259... Generator Loss: 1.8759
# Epoch 482/1000... Discriminator Loss: 0.9908... Generator Loss: 1.6262
# Epoch 483/1000... Discriminator Loss: 0.9284... Generator Loss: 1.7098
# Epoch 484/1000... Discriminator Loss: 0.9538... Generator Loss: 1.8268
# Epoch 485/1000... Discriminator Loss: 0.8691... Generator Loss: 1.7116
# Epoch 486/1000... Discriminator Loss: 0.9891... Generator Loss: 1.5538
# Epoch 487/1000... Discriminator Loss: 0.9777... Generator Loss: 1.4872
# Epoch 488/1000... Discriminator Loss: 0.9416... Generator Loss: 1.8636
# Epoch 489/1000... Discriminator Loss: 0.9874... Generator Loss: 1.7672
# Epoch 490/1000... Discriminator Loss: 0.8452... Generator Loss: 1.9208
# Epoch 491/1000... Discriminator Loss: 0.9633... Generator Loss: 1.5525
# Epoch 492/1000... Discriminator Loss: 0.8141... Generator Loss: 1.7494
# Epoch 493/1000... Discriminator Loss: 0.8097... Generator Loss: 1.8905
# Epoch 494/1000... Discriminator Loss: 0.8927... Generator Loss: 1.6352
# Epoch 495/1000... Discriminator Loss: 1.0042... Generator Loss: 1.7767
# Epoch 496/1000... Discriminator Loss: 0.9337... Generator Loss: 1.7118
# Epoch 497/1000... Discriminator Loss: 0.9159... Generator Loss: 1.7423
# Epoch 498/1000... Discriminator Loss: 0.8166... Generator Loss: 1.9531
# Epoch 499/1000... Discriminator Loss: 0.8953... Generator Loss: 1.8480
# Epoch 500/1000... Discriminator Loss: 0.8920... Generator Loss: 1.8792
# Epoch 501/1000... Discriminator Loss: 0.9248... Generator Loss: 2.1742
# Epoch 502/1000... Discriminator Loss: 0.9118... Generator Loss: 1.6457
# Epoch 503/1000... Discriminator Loss: 0.9663... Generator Loss: 1.7641
# Epoch 504/1000... Discriminator Loss: 0.9669... Generator Loss: 2.0345
# Epoch 505/1000... Discriminator Loss: 0.8719... Generator Loss: 1.6697
# Epoch 506/1000... Discriminator Loss: 0.8977... Generator Loss: 1.8900
# Epoch 507/1000... Discriminator Loss: 0.8510... Generator Loss: 1.9041
# Epoch 508/1000... Discriminator Loss: 0.8419... Generator Loss: 1.9585
# Epoch 509/1000... Discriminator Loss: 0.9036... Generator Loss: 1.7651
# Epoch 510/1000... Discriminator Loss: 0.9393... Generator Loss: 2.1512
# Epoch 511/1000... Discriminator Loss: 0.8847... Generator Loss: 1.7933
# Epoch 512/1000... Discriminator Loss: 1.0075... Generator Loss: 1.9091
# Epoch 513/1000... Discriminator Loss: 0.9750... Generator Loss: 1.4723
# Epoch 514/1000... Discriminator Loss: 0.9325... Generator Loss: 1.7958
# Epoch 515/1000... Discriminator Loss: 0.8966... Generator Loss: 1.7687
# Epoch 516/1000... Discriminator Loss: 0.9765... Generator Loss: 1.9123
# Epoch 517/1000... Discriminator Loss: 1.0307... Generator Loss: 1.5104
# Epoch 518/1000... Discriminator Loss: 0.9511... Generator Loss: 1.5764
# Epoch 519/1000... Discriminator Loss: 0.8770... Generator Loss: 2.0363
# Epoch 520/1000... Discriminator Loss: 1.0203... Generator Loss: 1.7673
# Epoch 521/1000... Discriminator Loss: 0.9976... Generator Loss: 1.5342
# Epoch 522/1000... Discriminator Loss: 0.9013... Generator Loss: 1.7035
# Epoch 523/1000... Discriminator Loss: 0.8254... Generator Loss: 1.8521
# Epoch 524/1000... Discriminator Loss: 0.8828... Generator Loss: 1.9069
# Epoch 525/1000... Discriminator Loss: 0.7957... Generator Loss: 2.1464
# Epoch 526/1000... Discriminator Loss: 0.8009... Generator Loss: 2.1314
# Epoch 527/1000... Discriminator Loss: 0.9588... Generator Loss: 1.6194
# Epoch 528/1000... Discriminator Loss: 0.9616... Generator Loss: 1.6200
# Epoch 529/1000... Discriminator Loss: 0.9881... Generator Loss: 1.6306
# Epoch 530/1000... Discriminator Loss: 1.0158... Generator Loss: 1.7629
# Epoch 531/1000... Discriminator Loss: 0.8781... Generator Loss: 1.6633
# Epoch 532/1000... Discriminator Loss: 1.1092... Generator Loss: 1.3471
# Epoch 533/1000... Discriminator Loss: 0.8577... Generator Loss: 1.7792
# Epoch 534/1000... Discriminator Loss: 0.9677... Generator Loss: 1.4817
# Epoch 535/1000... Discriminator Loss: 0.8489... Generator Loss: 1.7022
# Epoch 536/1000... Discriminator Loss: 0.9078... Generator Loss: 1.9306
# Epoch 537/1000... Discriminator Loss: 0.9948... Generator Loss: 1.6587
# Epoch 538/1000... Discriminator Loss: 0.9443... Generator Loss: 1.8291
# Epoch 539/1000... Discriminator Loss: 0.8668... Generator Loss: 1.9139
# Epoch 540/1000... Discriminator Loss: 0.9454... Generator Loss: 1.6598
# Epoch 541/1000... Discriminator Loss: 0.8462... Generator Loss: 1.7966
# Epoch 542/1000... Discriminator Loss: 0.9191... Generator Loss: 2.0596
# Epoch 543/1000... Discriminator Loss: 0.9520... Generator Loss: 1.9333
# Epoch 544/1000... Discriminator Loss: 1.0019... Generator Loss: 1.6283
# Epoch 545/1000... Discriminator Loss: 0.9679... Generator Loss: 1.8283
# Epoch 546/1000... Discriminator Loss: 0.9063... Generator Loss: 1.8641
# Epoch 547/1000... Discriminator Loss: 0.9507... Generator Loss: 1.6987
# Epoch 548/1000... Discriminator Loss: 0.9523... Generator Loss: 1.6190
# Epoch 549/1000... Discriminator Loss: 0.9057... Generator Loss: 1.8107
# Epoch 550/1000... Discriminator Loss: 0.8956... Generator Loss: 1.9092
# Epoch 551/1000... Discriminator Loss: 0.9854... Generator Loss: 1.9349
# Epoch 552/1000... Discriminator Loss: 0.8756... Generator Loss: 1.8624
# Epoch 553/1000... Discriminator Loss: 0.8933... Generator Loss: 1.9584
# Epoch 554/1000... Discriminator Loss: 0.9333... Generator Loss: 2.1365
# Epoch 555/1000... Discriminator Loss: 0.8629... Generator Loss: 2.1112
# Epoch 556/1000... Discriminator Loss: 0.9661... Generator Loss: 1.7634
# Epoch 557/1000... Discriminator Loss: 1.0410... Generator Loss: 1.6373
# Epoch 558/1000... Discriminator Loss: 0.8660... Generator Loss: 1.9537
# Epoch 559/1000... Discriminator Loss: 0.9513... Generator Loss: 1.8218
# Epoch 560/1000... Discriminator Loss: 0.8602... Generator Loss: 1.8046
# Epoch 561/1000... Discriminator Loss: 1.0444... Generator Loss: 1.6497
# Epoch 562/1000... Discriminator Loss: 0.9533... Generator Loss: 1.6349
# Epoch 563/1000... Discriminator Loss: 0.9943... Generator Loss: 1.7952
# Epoch 564/1000... Discriminator Loss: 0.8329... Generator Loss: 1.9507
# Epoch 565/1000... Discriminator Loss: 1.0062... Generator Loss: 1.5699
# Epoch 566/1000... Discriminator Loss: 0.8153... Generator Loss: 2.5173
# Epoch 567/1000... Discriminator Loss: 0.9727... Generator Loss: 1.5288
# Epoch 568/1000... Discriminator Loss: 0.9206... Generator Loss: 1.8570
# Epoch 569/1000... Discriminator Loss: 0.8526... Generator Loss: 2.2534
# Epoch 570/1000... Discriminator Loss: 0.9994... Generator Loss: 1.5158
# Epoch 571/1000... Discriminator Loss: 1.0208... Generator Loss: 1.7050
# Epoch 572/1000... Discriminator Loss: 1.0318... Generator Loss: 1.1433
# Epoch 573/1000... Discriminator Loss: 0.8484... Generator Loss: 1.7718
# Epoch 574/1000... Discriminator Loss: 0.8977... Generator Loss: 1.9576
# Epoch 575/1000... Discriminator Loss: 0.8256... Generator Loss: 1.7607
# Epoch 576/1000... Discriminator Loss: 0.9796... Generator Loss: 1.1236
# Epoch 577/1000... Discriminator Loss: 1.0781... Generator Loss: 1.6719
# Epoch 578/1000... Discriminator Loss: 1.0172... Generator Loss: 1.7091
# Epoch 579/1000... Discriminator Loss: 0.8641... Generator Loss: 1.7370
# Epoch 580/1000... Discriminator Loss: 0.9194... Generator Loss: 1.5686
# Epoch 581/1000... Discriminator Loss: 0.8803... Generator Loss: 1.7820
# Epoch 582/1000... Discriminator Loss: 0.9672... Generator Loss: 1.6096
# Epoch 583/1000... Discriminator Loss: 0.9320... Generator Loss: 1.7815
# Epoch 584/1000... Discriminator Loss: 1.0796... Generator Loss: 1.7412
# Epoch 585/1000... Discriminator Loss: 0.8489... Generator Loss: 1.5925
# Epoch 586/1000... Discriminator Loss: 0.9887... Generator Loss: 1.3799
# Epoch 587/1000... Discriminator Loss: 1.0369... Generator Loss: 1.3990
# Epoch 588/1000... Discriminator Loss: 0.7692... Generator Loss: 2.0572
# Epoch 589/1000... Discriminator Loss: 0.9664... Generator Loss: 1.6948
# Epoch 590/1000... Discriminator Loss: 1.0207... Generator Loss: 1.7495
# Epoch 591/1000... Discriminator Loss: 1.0692... Generator Loss: 1.6257
# Epoch 592/1000... Discriminator Loss: 0.7701... Generator Loss: 1.8767
# Epoch 593/1000... Discriminator Loss: 0.8839... Generator Loss: 1.7064
# Epoch 594/1000... Discriminator Loss: 0.8494... Generator Loss: 1.9997
# Epoch 595/1000... Discriminator Loss: 0.9278... Generator Loss: 1.6428
# Epoch 596/1000... Discriminator Loss: 0.9748... Generator Loss: 1.5941
# Epoch 597/1000... Discriminator Loss: 1.0938... Generator Loss: 1.6401
# Epoch 598/1000... Discriminator Loss: 0.7878... Generator Loss: 2.0260
# Epoch 599/1000... Discriminator Loss: 1.0448... Generator Loss: 1.6357
# Epoch 600/1000... Discriminator Loss: 1.0240... Generator Loss: 1.7718
# Epoch 601/1000... Discriminator Loss: 0.9692... Generator Loss: 1.8037
# Epoch 602/1000... Discriminator Loss: 0.8260... Generator Loss: 1.6738
# Epoch 603/1000... Discriminator Loss: 0.9625... Generator Loss: 1.9935
# Epoch 604/1000... Discriminator Loss: 0.8861... Generator Loss: 1.8875
# Epoch 605/1000... Discriminator Loss: 0.8300... Generator Loss: 2.1644
# Epoch 606/1000... Discriminator Loss: 1.0391... Generator Loss: 1.5246
# Epoch 607/1000... Discriminator Loss: 0.9150... Generator Loss: 1.7414
# Epoch 608/1000... Discriminator Loss: 0.9110... Generator Loss: 1.5086
# Epoch 609/1000... Discriminator Loss: 0.9822... Generator Loss: 2.0394
# Epoch 610/1000... Discriminator Loss: 0.9723... Generator Loss: 1.9236
# Epoch 611/1000... Discriminator Loss: 0.9151... Generator Loss: 1.7839
# Epoch 612/1000... Discriminator Loss: 0.8848... Generator Loss: 1.6929
# Epoch 613/1000... Discriminator Loss: 1.0412... Generator Loss: 1.7298
# Epoch 614/1000... Discriminator Loss: 0.9827... Generator Loss: 1.5889
# Epoch 615/1000... Discriminator Loss: 0.8315... Generator Loss: 1.9914
# Epoch 616/1000... Discriminator Loss: 0.9227... Generator Loss: 1.8050
# Epoch 617/1000... Discriminator Loss: 1.0074... Generator Loss: 1.7904
# Epoch 618/1000... Discriminator Loss: 0.9080... Generator Loss: 1.7391
# Epoch 619/1000... Discriminator Loss: 0.8455... Generator Loss: 1.9541
# Epoch 620/1000... Discriminator Loss: 0.8780... Generator Loss: 1.5749
# Epoch 621/1000... Discriminator Loss: 0.8995... Generator Loss: 1.9131
# Epoch 622/1000... Discriminator Loss: 0.9469... Generator Loss: 1.7732
# Epoch 623/1000... Discriminator Loss: 0.9077... Generator Loss: 2.1199
# Epoch 624/1000... Discriminator Loss: 1.1530... Generator Loss: 1.6760
# Epoch 625/1000... Discriminator Loss: 0.9446... Generator Loss: 1.8518
# Epoch 626/1000... Discriminator Loss: 0.9112... Generator Loss: 2.4725
# Epoch 627/1000... Discriminator Loss: 1.0046... Generator Loss: 1.7699
# Epoch 628/1000... Discriminator Loss: 0.9236... Generator Loss: 1.6207
# Epoch 629/1000... Discriminator Loss: 0.9071... Generator Loss: 1.9541
# Epoch 630/1000... Discriminator Loss: 0.8903... Generator Loss: 1.6910
# Epoch 631/1000... Discriminator Loss: 0.9985... Generator Loss: 2.0653
# Epoch 632/1000... Discriminator Loss: 0.9497... Generator Loss: 1.5275
# Epoch 633/1000... Discriminator Loss: 1.0565... Generator Loss: 1.7371
# Epoch 634/1000... Discriminator Loss: 0.9500... Generator Loss: 1.5341
# Epoch 635/1000... Discriminator Loss: 0.9961... Generator Loss: 1.5582
# Epoch 636/1000... Discriminator Loss: 0.9881... Generator Loss: 1.5898
# Epoch 637/1000... Discriminator Loss: 0.8139... Generator Loss: 1.6947
# Epoch 638/1000... Discriminator Loss: 1.0035... Generator Loss: 1.7714
# Epoch 639/1000... Discriminator Loss: 0.9911... Generator Loss: 1.4352
# Epoch 640/1000... Discriminator Loss: 0.9551... Generator Loss: 1.6984
# Epoch 641/1000... Discriminator Loss: 0.8580... Generator Loss: 2.0641
# Epoch 642/1000... Discriminator Loss: 0.8887... Generator Loss: 1.5987
# Epoch 643/1000... Discriminator Loss: 0.9441... Generator Loss: 2.0514
# Epoch 644/1000... Discriminator Loss: 0.8735... Generator Loss: 2.0048
# Epoch 645/1000... Discriminator Loss: 0.8736... Generator Loss: 2.0108
# Epoch 646/1000... Discriminator Loss: 0.8548... Generator Loss: 2.0137
# Epoch 647/1000... Discriminator Loss: 0.8695... Generator Loss: 1.7055
# Epoch 648/1000... Discriminator Loss: 0.8614... Generator Loss: 1.8003
# Epoch 649/1000... Discriminator Loss: 0.9052... Generator Loss: 1.9024
# Epoch 650/1000... Discriminator Loss: 0.9121... Generator Loss: 1.6981
# Epoch 651/1000... Discriminator Loss: 0.8165... Generator Loss: 1.5913
# Epoch 652/1000... Discriminator Loss: 0.8985... Generator Loss: 1.7089
# Epoch 653/1000... Discriminator Loss: 0.8418... Generator Loss: 1.7592
# Epoch 654/1000... Discriminator Loss: 0.9870... Generator Loss: 1.5361
# Epoch 655/1000... Discriminator Loss: 0.7966... Generator Loss: 1.8681
# Epoch 656/1000... Discriminator Loss: 0.9316... Generator Loss: 1.6067
# Epoch 657/1000... Discriminator Loss: 0.9425... Generator Loss: 1.7008
# Epoch 658/1000... Discriminator Loss: 0.9018... Generator Loss: 1.8355
# Epoch 659/1000... Discriminator Loss: 0.9165... Generator Loss: 2.0713
# Epoch 660/1000... Discriminator Loss: 0.8624... Generator Loss: 1.8678
# Epoch 661/1000... Discriminator Loss: 1.0735... Generator Loss: 1.8347
# Epoch 662/1000... Discriminator Loss: 0.7836... Generator Loss: 1.9790
# Epoch 663/1000... Discriminator Loss: 0.8594... Generator Loss: 1.9695
# Epoch 664/1000... Discriminator Loss: 0.8696... Generator Loss: 1.8791
# Epoch 665/1000... Discriminator Loss: 0.8195... Generator Loss: 1.7369
# Epoch 666/1000... Discriminator Loss: 0.8628... Generator Loss: 1.7324
# Epoch 667/1000... Discriminator Loss: 0.7974... Generator Loss: 1.9379
# Epoch 668/1000... Discriminator Loss: 0.9991... Generator Loss: 1.7550
# Epoch 669/1000... Discriminator Loss: 0.8454... Generator Loss: 1.9664
# Epoch 670/1000... Discriminator Loss: 0.8774... Generator Loss: 1.7853
# Epoch 671/1000... Discriminator Loss: 0.9947... Generator Loss: 1.4923
# Epoch 672/1000... Discriminator Loss: 0.9733... Generator Loss: 1.6438
# Epoch 673/1000... Discriminator Loss: 0.9506... Generator Loss: 2.1450
# Epoch 674/1000... Discriminator Loss: 0.9202... Generator Loss: 1.8850
# Epoch 675/1000... Discriminator Loss: 0.9606... Generator Loss: 2.2715
# Epoch 676/1000... Discriminator Loss: 0.7860... Generator Loss: 1.8701
# Epoch 677/1000... Discriminator Loss: 0.9820... Generator Loss: 1.8088
# ...
# Epoch 776/1000... Discriminator Loss: 0.8187... Generator Loss: 2.2400
# Epoch 777/1000... Discriminator Loss: 0.8522... Generator Loss: 1.7590
# Epoch 778/1000... Discriminator Loss: 1.0575... Generator Loss: 1.4690
# Epoch 779/1000... Discriminator Loss: 1.0338... Generator Loss: 1.7277
# Epoch 780/1000... Discriminator Loss: 0.9034... Generator Loss: 1.6636
# Epoch 781/1000... Discriminator Loss: 0.8310... Generator Loss: 1.6924
# Epoch 782/1000... Discriminator Loss: 0.8065... Generator Loss: 1.8898
# Epoch 783/1000... Discriminator Loss: 0.9132... Generator Loss: 1.7680
# Epoch 784/1000... Discriminator Loss: 0.9329... Generator Loss: 1.8013
# Epoch 785/1000... Discriminator Loss: 0.8746... Generator Loss: 2.1832
# Epoch 786/1000... Discriminator Loss: 0.8279... Generator Loss: 2.1656
# Epoch 787/1000... Discriminator Loss: 1.0755... Generator Loss: 1.6466
# Epoch 788/1000... Discriminator Loss: 0.9356... Generator Loss: 1.6456
# Epoch 789/1000... Discriminator Loss: 1.0176... Generator Loss: 1.6044
# Epoch 790/1000... Discriminator Loss: 0.9123... Generator Loss: 1.6979
# Epoch 791/1000... Discriminator Loss: 0.9420... Generator Loss: 1.8775
# Epoch 792/1000... Discriminator Loss: 0.8852... Generator Loss: 2.4840
# Epoch 793/1000... Discriminator Loss: 1.0459... Generator Loss: 1.9389
# Epoch 794/1000... Discriminator Loss: 0.9092... Generator Loss: 1.4381
# Epoch 795/1000... Discriminator Loss: 0.8592... Generator Loss: 1.9034
# Epoch 796/1000... Discriminator Loss: 0.9168... Generator Loss: 1.9230
# Epoch 797/1000... Discriminator Loss: 0.8998... Generator Loss: 2.2898
# Epoch 798/1000... Discriminator Loss: 0.9190... Generator Loss: 1.5617
# Epoch 799/1000... Discriminator Loss: 1.0298... Generator Loss: 1.7293
# Epoch 800/1000... Discriminator Loss: 0.9392... Generator Loss: 1.6632
# Epoch 801/1000... Discriminator Loss: 0.8479... Generator Loss: 1.7664
# Epoch 802/1000... Discriminator Loss: 0.9482... Generator Loss: 1.5213
# Epoch 803/1000... Discriminator Loss: 0.8612... Generator Loss: 1.9641
# Epoch 804/1000... Discriminator Loss: 0.9652... Generator Loss: 1.7345
# Epoch 805/1000... Discriminator Loss: 0.8164... Generator Loss: 2.3437
# Epoch 806/1000... Discriminator Loss: 0.8983... Generator Loss: 1.4983
# Epoch 807/1000... Discriminator Loss: 1.0087... Generator Loss: 1.9259
# Epoch 808/1000... Discriminator Loss: 0.8465... Generator Loss: 1.8319
# Epoch 809/1000... Discriminator Loss: 0.9177... Generator Loss: 1.8048
# Epoch 810/1000... Discriminator Loss: 0.9963... Generator Loss: 1.7004
# Epoch 811/1000... Discriminator Loss: 0.8448... Generator Loss: 2.2108
# Epoch 812/1000... Discriminator Loss: 0.8796... Generator Loss: 2.0652
# Epoch 813/1000... Discriminator Loss: 1.0096... Generator Loss: 1.7371
# Epoch 814/1000... Discriminator Loss: 0.8467... Generator Loss: 1.7836
# Epoch 815/1000... Discriminator Loss: 0.9229... Generator Loss: 1.6679
# Epoch 816/1000... Discriminator Loss: 0.9277... Generator Loss: 1.8708
# Epoch 817/1000... Discriminator Loss: 0.9211... Generator Loss: 2.3242
# Epoch 818/1000... Discriminator Loss: 0.7854... Generator Loss: 1.9674
# Epoch 819/1000... Discriminator Loss: 0.8612... Generator Loss: 2.0439
# Epoch 820/1000... Discriminator Loss: 0.9700... Generator Loss: 1.9458
# Epoch 821/1000... Discriminator Loss: 0.9416... Generator Loss: 2.0299
# Epoch 822/1000... Discriminator Loss: 0.9702... Generator Loss: 1.5453
# Epoch 823/1000... Discriminator Loss: 1.0108... Generator Loss: 1.8654
# Epoch 824/1000... Discriminator Loss: 0.7822... Generator Loss: 1.8986
# Epoch 825/1000... Discriminator Loss: 0.7648... Generator Loss: 1.6535
# Epoch 826/1000... Discriminator Loss: 0.9813... Generator Loss: 1.4713
# Epoch 827/1000... Discriminator Loss: 0.9646... Generator Loss: 2.2515
# Epoch 828/1000... Discriminator Loss: 0.8993... Generator Loss: 1.8242
# Epoch 829/1000... Discriminator Loss: 0.8575... Generator Loss: 1.8918
# Epoch 830/1000... Discriminator Loss: 0.8487... Generator Loss: 1.8425
# Epoch 831/1000... Discriminator Loss: 0.9125... Generator Loss: 1.6965
# Epoch 832/1000... Discriminator Loss: 0.9379... Generator Loss: 1.6623
# Epoch 833/1000... Discriminator Loss: 0.9337... Generator Loss: 1.7879
# Epoch 834/1000... Discriminator Loss: 0.8948... Generator Loss: 2.1413
# Epoch 835/1000... Discriminator Loss: 0.8338... Generator Loss: 2.0264
# Epoch 836/1000... Discriminator Loss: 0.8427... Generator Loss: 1.6914
# Epoch 837/1000... Discriminator Loss: 0.8757... Generator Loss: 1.9178
# Epoch 838/1000... Discriminator Loss: 0.8508... Generator Loss: 2.0751
# Epoch 839/1000... Discriminator Loss: 0.9883... Generator Loss: 1.8229
# Epoch 840/1000... Discriminator Loss: 0.9695... Generator Loss: 2.2602
# Epoch 841/1000... Discriminator Loss: 0.8936... Generator Loss: 1.5864
# Epoch 842/1000... Discriminator Loss: 0.8273... Generator Loss: 1.8480
# Epoch 843/1000... Discriminator Loss: 0.7575... Generator Loss: 2.5529
# Epoch 844/1000... Discriminator Loss: 0.8652... Generator Loss: 2.0142
# Epoch 845/1000... Discriminator Loss: 0.9143... Generator Loss: 2.0621
# Epoch 846/1000... Discriminator Loss: 0.9188... Generator Loss: 1.5991
# Epoch 847/1000... Discriminator Loss: 0.8882... Generator Loss: 2.0737
# Epoch 848/1000... Discriminator Loss: 0.9271... Generator Loss: 1.4357
# Epoch 849/1000... Discriminator Loss: 0.8468... Generator Loss: 2.1873
# Epoch 850/1000... Discriminator Loss: 0.8808... Generator Loss: 1.9373
# Epoch 851/1000... Discriminator Loss: 1.0298... Generator Loss: 1.5469
# Epoch 852/1000... Discriminator Loss: 0.8923... Generator Loss: 1.7131
# Epoch 853/1000... Discriminator Loss: 0.8430... Generator Loss: 2.0291
# Epoch 854/1000... Discriminator Loss: 0.8473... Generator Loss: 1.6437
# Epoch 855/1000... Discriminator Loss: 0.7895... Generator Loss: 1.7867
# Epoch 856/1000... Discriminator Loss: 1.0078... Generator Loss: 1.4343
# Epoch 857/1000... Discriminator Loss: 0.9808... Generator Loss: 1.8314
# Epoch 858/1000... Discriminator Loss: 0.7999... Generator Loss: 1.8800
# Epoch 859/1000... Discriminator Loss: 0.8209... Generator Loss: 1.6502
# Epoch 860/1000... Discriminator Loss: 0.8911... Generator Loss: 1.7692
# Epoch 861/1000... Discriminator Loss: 0.8811... Generator Loss: 1.6895
# Epoch 862/1000... Discriminator Loss: 0.8572... Generator Loss: 1.9743
# Epoch 863/1000... Discriminator Loss: 0.8234... Generator Loss: 2.0051
# Epoch 864/1000... Discriminator Loss: 0.8729... Generator Loss: 1.9952
# Epoch 865/1000... Discriminator Loss: 0.8841... Generator Loss: 1.6938
# Epoch 866/1000... Discriminator Loss: 0.8588... Generator Loss: 2.0181
# Epoch 867/1000... Discriminator Loss: 0.8110... Generator Loss: 1.9185
# Epoch 868/1000... Discriminator Loss: 0.8231... Generator Loss: 2.2368
# Epoch 869/1000... Discriminator Loss: 0.8086... Generator Loss: 1.8752
# Epoch 870/1000... Discriminator Loss: 0.9265... Generator Loss: 1.9537
# Epoch 871/1000... Discriminator Loss: 0.8706... Generator Loss: 1.6232
# Epoch 872/1000... Discriminator Loss: 0.8902... Generator Loss: 1.7499
# Epoch 873/1000... Discriminator Loss: 0.8240... Generator Loss: 1.8655
# Epoch 874/1000... Discriminator Loss: 0.8633... Generator Loss: 1.8047
# Epoch 875/1000... Discriminator Loss: 1.0076... Generator Loss: 1.7243
# Epoch 876/1000... Discriminator Loss: 0.8697... Generator Loss: 2.1455
# Epoch 877/1000... Discriminator Loss: 0.9385... Generator Loss: 1.9910
# Epoch 878/1000... Discriminator Loss: 0.9133... Generator Loss: 1.7591
# Epoch 879/1000... Discriminator Loss: 0.9312... Generator Loss: 1.3995
# Epoch 880/1000... Discriminator Loss: 0.8684... Generator Loss: 1.7439
# Epoch 881/1000... Discriminator Loss: 0.8516... Generator Loss: 1.8485
# Epoch 882/1000... Discriminator Loss: 0.8823... Generator Loss: 1.9092
# Epoch 883/1000... Discriminator Loss: 0.8454... Generator Loss: 1.8737
# Epoch 884/1000... Discriminator Loss: 0.8905... Generator Loss: 1.7800
# Epoch 885/1000... Discriminator Loss: 0.8245... Generator Loss: 1.7892
# Epoch 886/1000... Discriminator Loss: 1.0263... Generator Loss: 1.6088
# Epoch 887/1000... Discriminator Loss: 1.0013... Generator Loss: 1.6269
# Epoch 888/1000... Discriminator Loss: 0.8693... Generator Loss: 1.8791
# Epoch 889/1000... Discriminator Loss: 0.8549... Generator Loss: 2.0100
# Epoch 890/1000... Discriminator Loss: 0.9412... Generator Loss: 1.7614
# Epoch 891/1000... Discriminator Loss: 0.9673... Generator Loss: 1.6837
# Epoch 892/1000... Discriminator Loss: 0.7829... Generator Loss: 1.9697
# Epoch 893/1000... Discriminator Loss: 0.9818... Generator Loss: 1.8001
# Epoch 894/1000... Discriminator Loss: 0.8624... Generator Loss: 1.9759
# Epoch 895/1000... Discriminator Loss: 0.8634... Generator Loss: 2.3063
# Epoch 896/1000... Discriminator Loss: 0.9938... Generator Loss: 1.5751
# Epoch 897/1000... Discriminator Loss: 0.8142... Generator Loss: 2.2161
# Epoch 898/1000... Discriminator Loss: 0.9237... Generator Loss: 1.9035
# Epoch 899/1000... Discriminator Loss: 0.7964... Generator Loss: 1.9325
# Epoch 900/1000... Discriminator Loss: 0.9156... Generator Loss: 1.6862
# Epoch 901/1000... Discriminator Loss: 0.7918... Generator Loss: 2.1850
# Epoch 902/1000... Discriminator Loss: 0.7858... Generator Loss: 2.2234
# Epoch 903/1000... Discriminator Loss: 0.9911... Generator Loss: 1.4184
# Epoch 904/1000... Discriminator Loss: 0.9281... Generator Loss: 1.6714
# Epoch 905/1000... Discriminator Loss: 0.9034... Generator Loss: 2.0051
# Epoch 906/1000... Discriminator Loss: 0.8838... Generator Loss: 2.0767
# Epoch 907/1000... Discriminator Loss: 0.8699... Generator Loss: 2.0224
# Epoch 908/1000... Discriminator Loss: 0.8893... Generator Loss: 1.6245
# Epoch 909/1000... Discriminator Loss: 0.9044... Generator Loss: 1.8414
# Epoch 910/1000... Discriminator Loss: 0.9173... Generator Loss: 1.9076
# Epoch 911/1000... Discriminator Loss: 0.9368... Generator Loss: 1.9317
# Epoch 912/1000... Discriminator Loss: 0.9076... Generator Loss: 1.4980
# Epoch 913/1000... Discriminator Loss: 0.9100... Generator Loss: 1.7270
# Epoch 914/1000... Discriminator Loss: 0.8986... Generator Loss: 1.9548
# Epoch 915/1000... Discriminator Loss: 0.8677... Generator Loss: 1.8404
# Epoch 916/1000... Discriminator Loss: 0.7679... Generator Loss: 1.9243
# Epoch 917/1000... Discriminator Loss: 0.9641... Generator Loss: 1.7151
# Epoch 918/1000... Discriminator Loss: 0.9376... Generator Loss: 1.8011
# Epoch 919/1000... Discriminator Loss: 0.8161... Generator Loss: 1.8996
# Epoch 920/1000... Discriminator Loss: 0.9031... Generator Loss: 1.6956
# Epoch 921/1000... Discriminator Loss: 0.9794... Generator Loss: 1.9924
# Epoch 922/1000... Discriminator Loss: 0.8258... Generator Loss: 1.8913
# Epoch 923/1000... Discriminator Loss: 0.8586... Generator Loss: 1.7417
# Epoch 924/1000... Discriminator Loss: 0.8411... Generator Loss: 2.1464
# Epoch 925/1000... Discriminator Loss: 0.8765... Generator Loss: 1.8121
# Epoch 926/1000... Discriminator Loss: 0.9505... Generator Loss: 2.2628
# Epoch 927/1000... Discriminator Loss: 0.8565... Generator Loss: 1.8123
# Epoch 928/1000... Discriminator Loss: 0.8274... Generator Loss: 1.9220
# Epoch 929/1000... Discriminator Loss: 0.9295... Generator Loss: 1.6835
# Epoch 930/1000... Discriminator Loss: 0.9404... Generator Loss: 1.8763
# Epoch 931/1000... Discriminator Loss: 0.7704... Generator Loss: 2.1876
# Epoch 932/1000... Discriminator Loss: 0.9678... Generator Loss: 1.7087
# Epoch 933/1000... Discriminator Loss: 0.7453... Generator Loss: 2.2849
# Epoch 934/1000... Discriminator Loss: 0.8575... Generator Loss: 2.1367
# Epoch 935/1000... Discriminator Loss: 0.7861... Generator Loss: 1.9780
# Epoch 936/1000... Discriminator Loss: 0.8592... Generator Loss: 1.8132
# Epoch 937/1000... Discriminator Loss: 0.9009... Generator Loss: 1.9822
# Epoch 938/1000... Discriminator Loss: 0.8960... Generator Loss: 1.5838
# Epoch 939/1000... Discriminator Loss: 0.8882... Generator Loss: 2.2437
# Epoch 940/1000... Discriminator Loss: 0.8512... Generator Loss: 2.0118
# Epoch 941/1000... Discriminator Loss: 0.8365... Generator Loss: 1.9152
# Epoch 942/1000... Discriminator Loss: 0.9145... Generator Loss: 1.9325
# Epoch 943/1000... Discriminator Loss: 0.8451... Generator Loss: 2.3013
# Epoch 944/1000... Discriminator Loss: 0.8039... Generator Loss: 1.9006
# Epoch 945/1000... Discriminator Loss: 0.8995... Generator Loss: 1.7602
# Epoch 946/1000... Discriminator Loss: 0.9914... Generator Loss: 1.9726
# Epoch 947/1000... Discriminator Loss: 0.9497... Generator Loss: 1.4106
# Epoch 948/1000... Discriminator Loss: 0.7760... Generator Loss: 2.0877
# Epoch 949/1000... Discriminator Loss: 0.9543... Generator Loss: 2.0818
# Epoch 950/1000... Discriminator Loss: 1.0244... Generator Loss: 1.6410
# Epoch 951/1000... Discriminator Loss: 0.7873... Generator Loss: 2.3588
# Epoch 952/1000... Discriminator Loss: 0.8879... Generator Loss: 2.0432
# Epoch 953/1000... Discriminator Loss: 0.7201... Generator Loss: 1.8211
# Epoch 954/1000... Discriminator Loss: 0.8665... Generator Loss: 1.7635
# Epoch 955/1000... Discriminator Loss: 0.9186... Generator Loss: 1.8355
# Epoch 956/1000... Discriminator Loss: 0.8979... Generator Loss: 2.2125
# Epoch 957/1000... Discriminator Loss: 0.8521... Generator Loss: 2.0820
# Epoch 958/1000... Discriminator Loss: 0.9339... Generator Loss: 1.7545
# Epoch 959/1000... Discriminator Loss: 0.7667... Generator Loss: 1.9280
# Epoch 960/1000... Discriminator Loss: 0.8619... Generator Loss: 1.8410
# Epoch 961/1000... Discriminator Loss: 0.8637... Generator Loss: 1.7313
# Epoch 962/1000... Discriminator Loss: 0.9465... Generator Loss: 1.9269
# Epoch 963/1000... Discriminator Loss: 0.8667... Generator Loss: 1.7992
# Epoch 964/1000... Discriminator Loss: 0.7893... Generator Loss: 2.1074
# Epoch 965/1000... Discriminator Loss: 0.7340... Generator Loss: 2.3199
# Epoch 966/1000... Discriminator Loss: 0.8154... Generator Loss: 1.7112
# Epoch 967/1000... Discriminator Loss: 0.8870... Generator Loss: 1.8033
# Epoch 968/1000... Discriminator Loss: 0.7940... Generator Loss: 2.0924
# Epoch 969/1000... Discriminator Loss: 0.7908... Generator Loss: 2.1184
# Epoch 970/1000... Discriminator Loss: 0.8162... Generator Loss: 1.8214
# Epoch 971/1000... Discriminator Loss: 0.8817... Generator Loss: 2.0697
# Epoch 972/1000... Discriminator Loss: 0.9485... Generator Loss: 1.8446
# Epoch 973/1000... Discriminator Loss: 0.8673... Generator Loss: 1.7846
# Epoch 974/1000... Discriminator Loss: 0.8474... Generator Loss: 1.8183
# Epoch 975/1000... Discriminator Loss: 0.9533... Generator Loss: 1.8004
# Epoch 976/1000... Discriminator Loss: 0.8220... Generator Loss: 2.0912
# Epoch 977/1000... Discriminator Loss: 0.9654... Generator Loss: 1.7458
# Epoch 978/1000... Discriminator Loss: 0.8311... Generator Loss: 2.3037
# Epoch 979/1000... Discriminator Loss: 0.8604... Generator Loss: 1.8224
# Epoch 980/1000... Discriminator Loss: 0.8434... Generator Loss: 2.3416
# Epoch 981/1000... Discriminator Loss: 0.8022... Generator Loss: 1.8559
# Epoch 982/1000... Discriminator Loss: 0.7766... Generator Loss: 1.8053
# Epoch 983/1000... Discriminator Loss: 0.7991... Generator Loss: 2.3141
# Epoch 984/1000... Discriminator Loss: 0.7820... Generator Loss: 1.8268
# Epoch 985/1000... Discriminator Loss: 0.8487... Generator Loss: 1.8409
# Epoch 986/1000... Discriminator Loss: 0.9688... Generator Loss: 1.7985
# Epoch 987/1000... Discriminator Loss: 0.9447... Generator Loss: 1.7089
# Epoch 988/1000... Discriminator Loss: 0.8114... Generator Loss: 1.8968
# Epoch 989/1000... Discriminator Loss: 0.9619... Generator Loss: 1.6130
# Epoch 990/1000... Discriminator Loss: 0.8229... Generator Loss: 1.9390
# Epoch 991/1000... Discriminator Loss: 0.8380... Generator Loss: 2.1466
# Epoch 992/1000... Discriminator Loss: 0.8681... Generator Loss: 2.3308
# Epoch 993/1000... Discriminator Loss: 0.8943... Generator Loss: 1.8476
# Epoch 994/1000... Discriminator Loss: 0.8030... Generator Loss: 1.9722
# Epoch 995/1000... Discriminator Loss: 0.8465... Generator Loss: 1.9202
# Epoch 996/1000... Discriminator Loss: 0.8646... Generator Loss: 2.1062
# Epoch 997/1000... Discriminator Loss: 0.9214... Generator Loss: 1.8404
# Epoch 998/1000... Discriminator Loss: 0.8868... Generator Loss: 2.0777
# Epoch 999/1000... Discriminator Loss: 0.8137... Generator Loss: 1.7601
# Epoch 1000/1000... Discriminator Loss: 0.8405... Generator Loss: 1.7860

# %% [markdown]
# ## Training loss
#
# Here we'll check out the training losses for the generator and discriminator.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
import numpy as np
import pickle as pkl

def expsmooth(x,a):
    y = np.zeros(x.shape)
    y[0]=x[0]
    for i in range(1,len(y)):
        y[i] = a*y[i-1] + (1-a)*x[i]
    return y

fig, ax = plt.subplots()
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)
with open('losses.pkl', 'rb') as f:
    losses = pkl.load(f)
losses = np.array(losses)
a = 0.9
plt.plot(expsmooth(losses.T[0] - losses.T[2],a), label='Discriminator on fake')
#plt.plot(expsmooth(losses.T[1],a), label='Generator')
plt.plot(expsmooth(losses.T[2],a), label='Discriminator on real')
plt.plot(expsmooth(losses.T[3],a), label='Discriminator on fake from 25 epochs ago')
plt.title("Training Losses")
plt.grid()
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at images taken while training.

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('losses.pkl', 'rb') as f:
    losses = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 5, 7, 3, 0, 9. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs. With bonus optical illusion!

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise. Looks like 1, 9, and 8 show up first. Then, it learns 5 and 3.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. We just need to pass in a new latent vector $z$ and we'll get new samples!

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, reuse=True),
                   feed_dict={input_z: sample_z})
view_samples(0, [gen_samples])
# Out:
# (<matplotlib.figure.Figure at 0x7f0e74322128>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e5f3d4d68>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e5f3b9978>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e5f2e1470>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a83af60>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a80d320>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a7cae10>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a717f98>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a6dc160>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a6a92e8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a66a710>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a635860>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a72b080>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e5fe8ea58>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e601d68d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a564438>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f0e6a5326a0>]], dtype=object))
